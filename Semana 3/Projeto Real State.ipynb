# %% [markdown]
# ## Projeto Real State
# Este projeto foi desenvolvido em caráter fictício com o objetivo de colocar em prática os conhecimentos adquiridos durante a terceira semana do treinamento Aceleradev Data Science fornecido pela [Codenation](https://codenation.dev/).

# %% [markdown]
# ### Entendimento do Negócio
# Fomos contratados pela empresa **Real State**, especializada na administração de imóveis. O CEO da Real State deseja minimizar o custo com a etapa de avaliação dos imóveis, realizada atualmente por corretores imobiliários.
#
# <img src="house.svg" width="400" height="400"/>
#
# Nosso objetivo é fornecer uma plataforma capaz de estimar o valor do aluguel para o imóvel de acordo com as características fornecidas pelo proprietário do imóvel, além de permitir a inserção de imagens e descrição do imóvel. Automatizando todo o processo de disponibilização do imóvel na plataforma da Real State.

# %% [markdown]
# ### Entendimento e Limpeza dos Dados
# Nesta etapa iremos preparar os dados para a análise exploratória.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.externals import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
df_houses = pd.read_csv('houses_to_rent_v2.csv')
df_houses.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# 3                   17        1421
# 4                   11         836

# %% [markdown]
# Temos **10692 observações** e **13 atributos** em nosso conjunto de dados.

# %%
df_houses.shape
# Out:
# (10692, 13)

# %% [markdown]
# **Atributos**:
# * **city**: cidade onde o imóvel está localizado.
# * **area**: área do imóvel (m²).
# * **rooms**: quantidade de quartos.
# * **bathroom**: quantidade de banheiros.
# * **parking spaces**: quantidade de vagas no estacionamento.
# * **floor**: nº do andar.
# * **animal**: indica se o imóvel permite a presença de animais.
# * **furniture**: indice se o imóvel possuí mobília.
# * **hoa**: valor do condomínio.
# * **rent amount**: valor do aluguel.
# * **property tax**: IPTU.
# * **fire insurance**: seguro contra incêndio.
# * **total**: (rent amount + hoa + property tax + fire insurance).

# %%
df_houses.dtypes
# Out:
# city                   object
# area                    int64
# rooms                   int64
# bathroom                int64
# parking spaces          int64
# floor                  object
# animal                 object
# furniture              object
# hoa (R$)                int64
# rent amount (R$)        int64
# property tax (R$)       int64
# fire insurance (R$)     int64
# total (R$)              int64
# dtype: object

# %% [markdown]
# Não temos a ocorrência de valores nulos em nosso conjunto, portanto **não será necessário realizar a imputação de dados.**

# %%
df_houses.isna().sum()
# Out:
# city                   0
# area                   0
# rooms                  0
# bathroom               0
# parking spaces         0
# floor                  0
# animal                 0
# furniture              0
# hoa (R$)               0
# rent amount (R$)       0
# property tax (R$)      0
# fire insurance (R$)    0
# total (R$)             0
# dtype: int64

# %% [markdown]
# Iremos renomear algumas colunas com o objetivo de facilitar seu acesso posteriormente.

# %%
df_houses.rename(columns={'hoa (R$)':'hoa','rent amount (R$)':'rent_amount','property tax (R$)':'property_tax',
                    'fire insurance (R$)':'fire_insurance','total (R$)':'total'}, inplace=True)

# %%
df_houses.describe()
# Out:
#                area         rooms      bathroom  parking spaces           hoa  \
# count  10692.000000  10692.000000  10692.000000    10692.000000  1.069200e+04
# mean     149.217920      2.506079      2.236813        1.609147  1.174022e+03
# std      537.016942      1.171266      1.407198        1.589521  1.559231e+04
# min       11.000000      1.000000      1.000000        0.000000  0.000000e+00
# 25%       56.000000      2.000000      1.000000        0.000000  1.700000e+02
# 50%       90.000000      2.000000      2.000000        1.000000  5.600000e+02
# 75%      182.000000      3.000000      3.000000        2.000000  1.237500e+03
# max    46335.000000     13.000000     10.000000       12.000000  1.117000e+06
#
#         rent_amount   property_tax  fire_insurance         total
# count  10692.000000   10692.000000    10692.000000  1.069200e+04
# mean    3896.247194     366.704358       53.300879  5.490487e+03
# std     3408.545518    3107.832321       47.768031  1.648473e+04
# min      450.000000       0.000000        3.000000  4.990000e+02
# 25%     1530.000000      38.000000       21.000000  2.061750e+03
# 50%     2661.000000     125.000000       36.000000  3.581500e+03
# 75%     5000.000000     375.000000       68.000000  6.768000e+03
# max    45000.000000  313700.000000      677.000000  1.120000e+06

# %% [markdown]
# Iremos investigar alguns atributos considerando a discrepância verificada entre o percentil 75 e o valor máximo, além do desvio padrão em relação a média.
#
# Para remover os **outliers**, iremos utilizar a regra da amplitude interquartil, descartando os valores que ultrapassam o limite inferior e superior:
# <img src="iqr.png" width="500" height="500"/>

# %%
def lowerUpperLimit(data):
    Q1 = data.quantile(.25)
    Q3 = data.quantile(.75)
    IQR = Q3 - Q1
    minimum = Q1 - 1.5 * IQR
    maximum = Q3 + 1.5 * IQR
    
    return minimum, maximum

# %% [markdown]
# * **Area**

# %%
sns.set(style='whitegrid', font_scale=1.1, rc={"figure.figsize": [12, 5]})
sns.distplot(df_houses['area'], color='#41b6c4');

# %%
sns.boxplot('area', data=df_houses, color='#41b6c4');

# %%
lower_limit_area, upper_limit_area = lowerUpperLimit(df_houses['area'])
df_cleaned = df_houses.drop(df_houses.query('area < @lower_limit_area | area > @upper_limit_area').index)

# %% [markdown]
# Vamos verificar a distribuição do atributo *area* após a remoção dos outliers:

# %%
sns.distplot(df_cleaned['area'], color='#41b6c4');

# %%
sns.boxplot('area', data=df_cleaned, color='#41b6c4');

# %%
df_cleaned['area'].mean()
# Out:
# 116.06477045908184

# %% [markdown]
# Sem a presença de outliers somos capazer de analisar a distribuição do atributo _area_ e verificar que **a maioria dos imóveis possuem área entre 55 m² e 160 m², com o tamanho médio de 116 m²**.

# %% [markdown]
# * **Rent Amount**

# %%
sns.distplot(df_houses['rent_amount']);

# %%
sns.boxplot('rent_amount', data=df_houses);

# %%
lower_limit_rent, upper_limit_rent = lowerUpperLimit(df_houses['rent_amount'])
df_cleaned.drop(df_cleaned.query('rent_amount < @lower_limit_rent | rent_amount > @upper_limit_rent').index, inplace=True)

# %% [markdown]
# Agora vamos verificar como ficou a distribuição do atributo *rent_amount* após a remoção dos outliers:

# %%
sns.distplot(df_cleaned['rent_amount']);

# %%
sns.boxplot('rent_amount', data=df_cleaned);

# %%
df_cleaned['rent_amount'].mean()
# Out:
# 3064.944305120167

# %% [markdown]
# Após a remoção dos outliers, podemos observar que **a maioria dos imóveis custam entre R\\$ 1500 e R\\$ 4000 para locação, com o valor médio de R\$ 3064**.

# %% [markdown]
# * **Floor**

# %%
df_cleaned['floor'].unique()
# Out:
# array(['7', '20', '6', '2', '1', '4', '10', '11', '24', '-', '9', '8',
#        '17', '18', '5', '3', '13', '15', '16', '14', '26', '21', '12',
#        '19', '22', '27', '23', '25', '46', '28', '29', '301', '51', '32'],
#       dtype=object)

# %% [markdown]
# Apesar de ser um valor inteiro, o atributo _floor_ está representado como string.

# %%
df_cleaned['floor'].replace(to_replace='-', value=0, inplace=True)
df_cleaned['floor'] = df_cleaned['floor'].astype(int)

# %%
sns.distplot(df_cleaned['floor']);

# %%
df_cleaned['floor'].describe()
# Out:
# count    9570.000000
# mean        5.127482
# std         6.029420
# min         0.000000
# 25%         1.000000
# 50%         4.000000
# 75%         8.000000
# max       301.000000
# Name: floor, dtype: float64

# %%
lower_limit_floor, upper_limit_floor = lowerUpperLimit(df_cleaned['floor'])
lower_limit_floor, upper_limit_floor
# Out:
# (-9.5, 18.5)

# %% [markdown]
# Antes de remover os valores que ultrapassam o limite, é importante verificar se faz sentido para o problema. Neste caso, é comum em grandes centros prédios residenciais que ultrapassam o limite de 18.5 andares. Arranha-Céus são prédios que ultrapassam 40 andares, vamos verificar se temos arranha-céus em nosso conjunto de dados:

# %%
df_cleaned[df_cleaned['floor'] > 40]
# Out:
#                 city  area  rooms  bathroom  parking spaces  floor animal  \
# 1654       São Paulo   353      4         5               5     46  acept
# 2562  Belo Horizonte    80      3         2               2    301  acept
# 5694        Campinas    64      2         2               2     51  acept
#
#           furniture   hoa  rent_amount  property_tax  fire_insurance  total
# 1654  not furnished  3000        10000             0             127  13130
# 2562  not furnished   750         2600           164              35   3549
# 5694  not furnished   800         1900           129              25   2854

# %% [markdown]
# Considerações:
# * Atualmente, o [prédio mais alto de São Paulo](https://www.imovelweb.com.br/noticias/arquitetura/os-5-predios-mais-altos-brasil/) é o Mirante do Vale, com 51 andares;
# * O [prédio mais alto de campinas](https://www.acidadeon.com/campinas/cotidiano/cidades/NOT,0,0,1347473,predio+mais+alto+de+campinas+edificio+mirante+tem+44+anos.aspx) tem 30 andares;
# * O [prédio mais alto do mundo](https://casavogue.globo.com/Arquitetura/Edificios/noticia/2019/10/conheca-os-10-predios-mais-altos-do-mundo.html#:~:text=Burj%20Khalifa%20(Emirados%20%C3%81rabes)&text=%C3%89%20do%20Burj%20Khalifa%2C%20em,828%20metros%20e%20160%20andares.) possuí 160 andares, portanto, a ocorrência do prédio em Belo Horizonte com 301 andares se trata de um erro no conjunto de dados.

# %% [markdown]
# De acordo com as considerações feitas anteriormente, iremos manter apenas o imóvel localizado em São Paulo.

# %%
df_cleaned.drop(df_cleaned.loc[(df_cleaned['floor'] > 46)].index, inplace=True)

# %% [markdown]
# Vamos verificar a distribuição dos nossos dados após a remoção dos **outliers**:

# %%
sns.distplot(df_cleaned['floor']);

# %%
sns.boxplot(df_cleaned['floor']);

# %% [markdown]
# Analisando a distribuição do atributo *floor*, é possível verificar que a **maioria dos imóveis estão localizados no térreo** e que **75% dos imóveis estão localizados a menos de 10 andares.**

# %% [markdown]
# * **Hoa (Taxa de condomínio)**

# %%
sns.distplot(df_cleaned['hoa']);

# %%
lower_limit_hoa, upper_limit_hoa = lowerUpperLimit(df_cleaned['hoa'])
df_cleaned.drop(df_cleaned.query('hoa < @lower_limit_hoa | hoa > @upper_limit_hoa').index, inplace=True)

# %%
sns.distplot(df_cleaned['hoa']);

# %%
sns.boxplot(df_cleaned['hoa']);

# %% [markdown]
# **A maioria dos imóveis não possuem cobrança de taxa de condomínio e 75% dos imóveis possuem a taxa inferior a 955 reais**.

# %% [markdown]
# * **Property Tax (IPTU)**

# %%
sns.distplot(df_cleaned['property_tax']);

# %%
lower_limit_tax, upper_limit_tax = lowerUpperLimit(df_cleaned['property_tax'])
df_cleaned.drop(df_cleaned.query('property_tax < @lower_limit_tax | property_tax > @upper_limit_tax').index, inplace=True)

# %%
sns.distplot(df_cleaned['property_tax']);

# %%
sns.boxplot(df_cleaned['property_tax']);

# %% [markdown]
# Podemos observar após a remoção de outliers que **a maioria dos imóveis não possuem a cobrança de IPTU e que 75% dos imóveis possuem o valor do imposto inferior a R$200.**

# %% [markdown]
# ### Análise Exploratória

# %% [markdown]
# * **Rent_Amount**

# %% [markdown]
# **Qual cidade possui o valor médio mais alto para locação?**

# %%
city_rent = df_cleaned.groupby('city')['rent_amount'].mean()
city_rent = pd.DataFrame({'city':city_rent.index, 
                          'average_rent':city_rent.values}).sort_values(by='average_rent', ascending=False)
sns.barplot('city', 'average_rent', data=city_rent, color = '#1d91c0')
plt.xlabel('Cidade')
plt.ylabel('Custo médio do aluguel')
plt.title('Valor médio do aluguel por cidade');

# %% [markdown]
# **São Paulo é a cidade que possuí o custo médio mais alto para locação**, em contrapartida, a cidade de **Campinas possuí o valor médio de aluguel mais baixo, sendo inferior a R$2000.**

# %% [markdown]
# * **Area**

# %% [markdown]
# **Qual cidade possui os imóveis com o maior tamanho médio?**

# %%
city_area = df_cleaned.groupby('city')['area'].mean()
city_area = pd.DataFrame({'city':city_area.index, 
                          'average_area':city_area.values}).sort_values(by='average_area', ascending=False)
sns.barplot('city', 'average_area', data=city_area, color='#41b6c4')
plt.xlabel('Cidade')
plt.ylabel('Tamanho médio (m²)')
plt.title('Tamanho médio dos imóveis por cidade');

# %% [markdown]
# Em média, **os aluguéis em São Paulo são mais caros, porém os imóveis são menores em comparação com Belo Horizonte. A cidade do Rio de Janeiro possuí em média os menores imóveis, com tamanho médio inferior a 85 m².**

# %% [markdown]
# * **Floor**

# %% [markdown]
# **Imóveis localizados em andares mais altos possuem aluguel mais elevado?**

# %%
floor_rent = df_cleaned.groupby('floor')['rent_amount'].mean()
floor_rent = pd.DataFrame({'floor':floor_rent.index, 
                          'average_rent':floor_rent.values}).sort_values(by='floor', ascending=False)
plt.plot('floor', 'average_rent', '-bo', data=floor_rent[floor_rent['floor'] > 0])
plt.xlabel('Andar')
plt.ylabel('Custo médio do aluguel')
plt.title('Valor médio do aluguel de acordo com o andar');

# %% [markdown]
# Apesar de algumas oscilações, podemos verificar que em média, **o custo médio do aluguel aumenta de acordo com o andar que o imóvel está localizado.**

# %% [markdown]
# * **Hoa (Taxa de condomínio)**

# %% [markdown]
# **Imóveis que permitem animais possuem em média maior taxa de condomínio?**

# %%
aux_animal = df_cleaned.copy()
aux_animal['animal'].replace(to_replace=1, value='Permite', inplace=True)
aux_animal['animal'].replace(to_replace=0, value='Não permite', inplace=True)

# %%
sns.barplot(x='animal', y='hoa', data=aux_animal[aux_animal['hoa'] > 0], palette="Blues_d");
plt.xlabel('Animal')
plt.ylabel('Taxa de condomínio')
plt.title('Taxa de condomínio por permitirem animais');

# %% [markdown]
# **O fato do condomínio permitir animal não influência consideravelmente o valor da taxa.**

# %% [markdown]
# **Imóveis que permitem animais possuem em média aluguel mais caro?**

# %%
sns.barplot(x='animal', y='rent_amount', data=aux_animal, palette="Blues_d");
plt.xlabel('Animal')
plt.ylabel('Valor médio do aluguel')
plt.title('Valor médio do aluguel por permitirem animais');

# %% [markdown]
# Em média, **os imóveis que permitem animais possuem um pequeno aumento no valor do aluguel.**

# %% [markdown]
# * **Furniture**

# %% [markdown]
# **Imóveis mobiliados possuem aluguel mais elevado?**

# %%
sns.barplot(x='furniture', y='rent_amount', data=df_cleaned, palette="Blues_d");

# %%
df_cleaned[df_cleaned['furniture'] == 'furnished']['rent_amount'].mean() - df_cleaned[df_cleaned['furniture'] == 'not furnished']['rent_amount'].mean()
# Out:
# 942.5205305356103

# %% [markdown]
# Em média, **imóveis mobiliados custam em média R$942 a mais para serem alugados.**

# %% [markdown]
# * **Property Tax (IPTU)**

# %% [markdown]
# Identificamos na etapa anterior que a maioria dos imóveis não possuem a cobrança de IPTU. O IPTU é cobrado para imóveis cujo valor venal é superior a R$70000. O valor venal indica qual o valor do imóvel, de acordo com o governo, é calculado com base na quantidade de metros quadrados que a residência possuí e no valor médio do metro quadrado da sua região.

# %% [markdown]
# Vamos analisar os atributos referente a área do imóvel, quantidade quartos, banheiros e valor do aluguel para imóveis que **não possuem a cobrança de IPTU.**

# %%
no_tax = df_cleaned[df_cleaned['property_tax'] == 0]

# %%
no_tax.groupby('city')[['area', 'rooms', 'bathroom', 'rent_amount']].mean().style.format({"area": "{:20,.2f}",
                                                                                          "rooms": "{:20,.2f}",
                                                                                          "bathroom": "{:20,.2f}",
                                                                                          "rent_amount": "${:20,.0f}"})\
                                                                                 .highlight_max(color='lightgreen')\
                                                                                 .highlight_min(color='#de425b')
# Out:
# <style  type="text/css" >
#     #T_a0569654_b711_11ea_8fde_7824afe42db1row0_col0 {
#             background-color:  lightgreen;
#             : ;
#         }    #T_a0569654_b711_11ea_8fde_7824afe42db1row0_col1 {
#             background-color:  lightgreen;
#             : ;
#         }    #T_a0569654_b711_11ea_8fde_7824afe42db1row1_col2 {
#             background-color:  lightgreen;
#             : ;
#         }    #T_a0569654_b711_11ea_8fde_7824afe42db1row3_col0 {
#             : ;
#             background-color:  #de425b;
#         }    #T_a0569654_b711_11ea_8fde_7824afe42db1row3_col1 {
#             : ;
#             background-color:  #de425b;
#         }    #T_a0569654_b711_11ea_8fde_7824afe42db1row3_col2 {
#             : ;
#             background-color:  #de425b;
#         }    #T_a0569654_b711_11ea_8fde_7824afe42db1row3_col3 {
#             : ;
#             background-color:  #de425b;
#         }    #T_a0569654_b711_11ea_8fde_7824afe42db1row4_col3 {
#             background-color:  lightgreen;
#             : ;
#         }</style><table id="T_a0569654_b711_11ea_8fde_7824afe42db1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >area</th>        <th class="col_heading level0 col1" >rooms</th>        <th class="col_heading level0 col2" >bathroom</th>        <th class="col_heading level0 col3" >rent_amount</th>    </tr>    <tr>        <th class="index_name level0" >city</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a0569654_b711_11ea_8fde_7824afe42db1level0_row0" class="row_heading level0 row0" >Belo Horizonte</th>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row0_col0" class="data row0 col0" >               77.07</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row0_col1" class="data row0 col1" >                2.08</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row0_col2" class="data row0 col2" >                1.48</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row0_col3" class="data row0 col3" >$               1,681</td>
#             </tr>
#             <tr>
#                         <th id="T_a0569654_b711_11ea_8fde_7824afe42db1level0_row1" class="row_heading level0 row1" >Campinas</th>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row1_col0" class="data row1 col0" >               72.65</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row1_col1" class="data row1 col1" >                1.99</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row1_col2" class="data row1 col2" >                1.53</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row1_col3" class="data row1 col3" >$               1,713</td>
#             </tr>
#             <tr>
#                         <th id="T_a0569654_b711_11ea_8fde_7824afe42db1level0_row2" class="row_heading level0 row2" >Porto Alegre</th>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row2_col0" class="data row2 col0" >               66.56</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row2_col1" class="data row2 col1" >                1.68</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row2_col2" class="data row2 col2" >                1.37</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row2_col3" class="data row2 col3" >$               1,762</td>
#             </tr>
#             <tr>
#                         <th id="T_a0569654_b711_11ea_8fde_7824afe42db1level0_row3" class="row_heading level0 row3" >Rio de Janeiro</th>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row3_col0" class="data row3 col0" >               51.18</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row3_col1" class="data row3 col1" >                1.53</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row3_col2" class="data row3 col2" >                1.18</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row3_col3" class="data row3 col3" >$               1,582</td>
#             </tr>
#             <tr>
#                         <th id="T_a0569654_b711_11ea_8fde_7824afe42db1level0_row4" class="row_heading level0 row4" >São Paulo</th>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row4_col0" class="data row4 col0" >               76.70</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row4_col1" class="data row4 col1" >                1.85</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row4_col2" class="data row4 col2" >                1.50</td>
#                         <td id="T_a0569654_b711_11ea_8fde_7824afe42db1row4_col3" class="data row4 col3" >$               2,489</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# A cidade do **Rio de Janeiro possuí a menor média para todos atributos, incluindo área, quantidade de banheiros, quartos e consequentemente, o menor aluguel** em comparação com as outras cidades. **São Paulo possuí a maior média de aluguel**, enquanto **Belo Horizonte tem a maior média de área e quantidade de quartos**. Por fim, entre todas as cidades, **Campinas possuí a maior quantidade média de banheiros.**

# %% [markdown]
# A seguir, iremos analisar os atributos anteriores para imóveis que **possuem a cobrança de IPTU.**

# %%
property_tax = df_cleaned[df_cleaned['property_tax'] > 0]
property_tax.groupby('city')[['area', 'rooms', 'bathroom', 'rent_amount']].mean().style.format({"area": "{:20,.2f}",
                                                                                          "rooms": "{:20,.2f}",
                                                                                          "bathroom": "{:20,.2f}",
                                                                                          "rent_amount": "${:20,.0f}"})\
                                                                                 .highlight_max(color='lightgreen')\
                                                                                 .highlight_min(color='#de425b')
# Out:
# <style  type="text/css" >
#     #T_3a953dba_b70d_11ea_9b7c_7824afe42db1row0_col0 {
#             background-color:  lightgreen;
#             : ;
#         }    #T_3a953dba_b70d_11ea_9b7c_7824afe42db1row0_col1 {
#             background-color:  lightgreen;
#             : ;
#         }    #T_3a953dba_b70d_11ea_9b7c_7824afe42db1row0_col2 {
#             background-color:  lightgreen;
#             : ;
#         }    #T_3a953dba_b70d_11ea_9b7c_7824afe42db1row1_col3 {
#             : ;
#             background-color:  #de425b;
#         }    #T_3a953dba_b70d_11ea_9b7c_7824afe42db1row2_col1 {
#             : ;
#             background-color:  #de425b;
#         }    #T_3a953dba_b70d_11ea_9b7c_7824afe42db1row3_col0 {
#             : ;
#             background-color:  #de425b;
#         }    #T_3a953dba_b70d_11ea_9b7c_7824afe42db1row3_col2 {
#             : ;
#             background-color:  #de425b;
#         }    #T_3a953dba_b70d_11ea_9b7c_7824afe42db1row4_col3 {
#             background-color:  lightgreen;
#             : ;
#         }</style><table id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >area</th>        <th class="col_heading level0 col1" >rooms</th>        <th class="col_heading level0 col2" >bathroom</th>        <th class="col_heading level0 col3" >rent_amount</th>    </tr>    <tr>        <th class="index_name level0" >city</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1level0_row0" class="row_heading level0 row0" >Belo Horizonte</th>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row0_col0" class="data row0 col0" >              124.04</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row0_col1" class="data row0 col1" >                2.83</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row0_col2" class="data row0 col2" >                2.03</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row0_col3" class="data row0 col3" >$               2,461</td>
#             </tr>
#             <tr>
#                         <th id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1level0_row1" class="row_heading level0 row1" >Campinas</th>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row1_col0" class="data row1 col0" >               98.91</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row1_col1" class="data row1 col1" >                2.26</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row1_col2" class="data row1 col2" >                1.74</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row1_col3" class="data row1 col3" >$               1,927</td>
#             </tr>
#             <tr>
#                         <th id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1level0_row2" class="row_heading level0 row2" >Porto Alegre</th>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row2_col0" class="data row2 col0" >               90.03</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row2_col1" class="data row2 col1" >                2.10</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row2_col2" class="data row2 col2" >                1.64</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row2_col3" class="data row2 col3" >$               2,034</td>
#             </tr>
#             <tr>
#                         <th id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1level0_row3" class="row_heading level0 row3" >Rio de Janeiro</th>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row3_col0" class="data row3 col0" >               87.13</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row3_col1" class="data row3 col1" >                2.15</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row3_col2" class="data row3 col2" >                1.61</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row3_col3" class="data row3 col3" >$               2,626</td>
#             </tr>
#             <tr>
#                         <th id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1level0_row4" class="row_heading level0 row4" >São Paulo</th>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row4_col0" class="data row4 col0" >              100.18</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row4_col1" class="data row4 col1" >                2.22</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row4_col2" class="data row4 col2" >                1.90</td>
#                         <td id="T_3a953dba_b70d_11ea_9b7c_7824afe42db1row4_col3" class="data row4 col3" >$               3,182</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **São Paulo mantém a maior média de aluguel** para imóveis com e sem a cobrança de IPTU. Assim como, **Belo Horizonte que mantém a maior média para área e quantidade de quartos em ambas situações, além da maior quantidade de banheiros** para imóveis onde o imposto é cobrado. **Rio de Janeiro possuí a menor média para área e quantidade de quartos** em ambas situações. **Porto Alegre possuí a menor média de quartos** para imóveis com a cobraça de IPTU. E por fim, **Campinas possuí em média o menor aluguel** para imóveis onde o imposto é cobrado.

# %% [markdown]
# ### Preparação dos Dados
# Nesta etapa, os dados serão preparados e selecionados para o modelo.

# %%
df_prepared = df_cleaned.copy()

# %% [markdown]
# * **Animal**

# %% [markdown]
# O atributo _animal_ se trata de uma variável categórica binária que expressa se um imóvel permite ou não a presença de imóveis. Iremos transforma-lá em inteiro, onde a presença permitida será representada por 1 (True) e não permitida por 0 (False).

# %%
df_prepared['animal'].value_counts()
# Out:
# acept        6757
# not acept    2023
# Name: animal, dtype: int64

# %%
df_prepared['animal'].replace(to_replace='acept', value=1, inplace=True)
df_prepared['animal'].replace(to_replace='not acept', value=0, inplace=True)

# %% [markdown]
# * **Furniture**

# %% [markdown]
# O atributo *furniture* indica se o imóvel possuí mobília, iremos utilizar a mesma abordagem adotada para o atributo *animal*, onde a presença de mobília será representada por 1 (True) e a ausência por 0 (False).

# %%
df_prepared['furniture'].value_counts()
# Out:
# not furnished    6776
# furnished        2004
# Name: furniture, dtype: int64

# %%
df_prepared['furniture'].replace(to_replace='furnished', value=1, inplace=True)
df_prepared['furniture'].replace(to_replace='not furnished', value=0, inplace=True)

# %% [markdown]
# * **City**

# %% [markdown]
# A grande maioria dos algoritmos de machine learning não aceitam valores no formato texto, portanto realizar a transformação para o formato adequado.

# %%
city_num = pd.get_dummies(df_prepared['city'])
df_prepared = pd.concat([df_prepared, city_num],axis=1)
df_prepared.drop(['city'], axis=1, inplace=True)

# %% [markdown]
# * **Correlação**

# %% [markdown]
# Como desejamos prever o valor do aluguel dado as características fornecidas pelo usuário, *rent_amount* é nosso atributo alvo. Portanto, vamos verificar qual a correlação dos demais atributos com o valor do aluguel.

# %%
df_prepared.corr()['rent_amount'].sort_values(ascending=False)
# Out:
# rent_amount       1.000000
# fire_insurance    0.982662
# area              0.634408
# bathroom          0.609849
# total             0.566109
# parking spaces    0.500811
# rooms             0.482616
# hoa               0.371706
# São Paulo         0.253240
# furniture         0.191642
# floor             0.079827
# animal            0.064892
# property_tax      0.039593
# Rio de Janeiro   -0.046596
# Belo Horizonte   -0.048110
# Campinas         -0.144894
# Porto Alegre     -0.157382
# Name: rent_amount, dtype: float64

# %% [markdown]
# Podemos verificar uma **altíssima correlação entre *fire_insurance* e *rent_amount*, tratando de um caso de multicolinearidade**. Uma regressão não é capaz de fornecer uma solução bem definida na presença de multicolinearidade, portanto iremos remover o atributo *fire_insurance*, assim como os atributos com correlação nula. Além do atributo *total*, considerando que tal valor será fornecido pela aplicação após obtermos o valor previsto para o aluguel.

# %%
features = df_prepared.columns.drop(['fire_insurance','total','floor','animal','property_tax','Rio de Janeiro','Belo Horizonte'])
features
# Out:
# Index(['area', 'rooms', 'bathroom', 'parking spaces', 'furniture', 'hoa',
#        'rent_amount', 'Campinas', 'Porto Alegre', 'São Paulo'],
#       dtype='object')

# %% [markdown]
# ### Construção e Avaliação do Modelo

# %%
df = df_prepared[features]

# %%
X = df.drop(columns='rent_amount')
y = df['rent_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# Primeiramente, iremos implementar um modelo base utilizando [Regressão Linear](https://medium.com/@bruno.dorneles/regress%C3%A3o-linear-conceitos-e-implementa%C3%A7%C3%A3o-com-python-232c19e00f03):

# %%
model_base = LinearRegression(normalize=True)
model_base.fit(X_train, y_train);

# %%
y_pred_lr = model_base.predict(X_test)
mean_absolute_error(y_pred_lr, y_test)
# Out:
# 902.7324627689522

# %% [markdown]
# A seguir, implementaremos um modelo de regressão utilizando Random Forest e verificar se obtemos um menor erro médio absoluto:

# %%
model_final = RandomForestRegressor()
model_final.fit(X_train, y_train);

# %%
y_pred_rf = model_final.predict(X_test)
mean_absolute_error(y_pred_rf, y_test)
# Out:
# 879.5100331421398

# %% [markdown]
# Obtemos melhor resultado através do modelo implementado com Random Forest. Poderíamos realizar o ajuste dos parâmetros em busca de um melhor resultado, mas não é foco deste projeto. Por fim, iremos salvar o modelo final para ser utilizado na aplicação:

# %%
joblib.dump(model_final, "model_final.pkl")

# %% [markdown]
# ### Referências
# * [Mãos à Obra: Aprendizado de Máquina com Scikit-Learn & TensorFlow](https://www.amazon.com.br/M%C3%A3os-Obra-Aprendizado-Scikit-Learn-TensorFlow/dp/8550803812)
# * [Towards Data Science - Understanding Boxplots](https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51)
# * [Towards Data Science - Style Pandas Dataframe Like a Master](https://towardsdatascience.com/style-pandas-dataframe-like-a-master-6b02bf6468b0)

# %% [markdown]
# Deixa sua crítica ou sugestão e me ajude a evoluir😉
# * [LinkedIn](https://www.linkedin.com/in/bruno-dorneles/)
# * [GitHub](https://github.com/BrunoDorneles)
